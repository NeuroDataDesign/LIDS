# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../j2/')

from util import calculate_stats, remove_labels, overlay_images
from quality import compute_overlap_array
from graphing import graph_performance
from skimage.io import imread

# %%
annotation = imread('../data/annotation.tiff')
predictions = imread('../data/results.tiff')

# %% [markdown]
# ### Detections using slicespan=2
# There are total of 2712 putative synapses.
#
# * Precision = 0.072
# * Recall = 0.52
# * F1 = 0.13

# %%
overlaps = compute_overlap_array(predictions, annotation)
print(calculate_stats(overlaps))
graph_performance(False, PLOS=overlaps)
# Out:
# (0.12168141592920353, 0.86842105263157898, 0.21345407503234154)

# %%
img = remove_labels(predictions, 1)

# %%
overlaps = compute_overlap_array(img, annotation)
print(calculate_stats(overlaps))
graph_performance(False, PLOS=overlaps)
# Out:
# (0.19296933433059088, 0.67894736842105263, 0.30052417006406523)

# %% [markdown]
# ### Detections using slicespan=1
# There are 8496 putative synapses.
#
# * Precision = 0.042
# * Recall = 0.94
# * F1 = 0.08

# %%
predictions = imread('../data/results_singles_span.tiff')

# %%
overlaps = compute_overlap_array(predictions, annotation)
print(calculate_stats(overlaps))
graph_performance(False, PLOS=overlaps)
# Out:
# (0.053319209039548024, 1.1921052631578948, 0.10207300585849483)

# %%
img = remove_labels(predictions, 1)

# %%
overlaps = compute_overlap_array(img, annotation)
print(calculate_stats(overlaps))
graph_performance(False, PLOS=overlaps)
# Out:
# (0.088489208633093522, 0.97105263157894739, 0.16219780219780219)
